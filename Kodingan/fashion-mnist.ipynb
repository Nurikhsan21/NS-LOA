# %%
import tensorflow as tf
import numpy as np
import time, gc, os, json, warnings
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (classification_report, confusion_matrix,
                             accuracy_score, precision_score,
                             recall_score, f1_score)

# %%
warnings.filterwarnings('ignore')

# ---------- GPU CONFIG ----------
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"✓ GPUs: {len(gpus)}")
else:
    print("⚠ No GPU - using CPU")
tf.keras.mixed_precision.set_global_policy('float32')

# ---------- LOAD MNIST ----------
print("="*60); print("LOADING FASHION-MNIST DATASET"); print("="*60)
(x_train_full, y_train_full), (x_test_full, y_test_full) = \
    tf.keras.datasets.fashion_mnist.load_data()

x_train_full = x_train_full.astype('float32') / 255.0
x_test_full  = x_test_full.astype('float32')  / 255.0
x_train_full = x_train_full[..., np.newaxis]   # (60000, 28, 28, 1)
x_test_full  = x_test_full[..., np.newaxis]    # (10000, 28, 28, 1)
y_train_full = y_train_full.flatten().astype('int32')
y_test_full  = y_test_full.flatten().astype('int32')
CLASS_NAMES = ['T-shirt/top','Trouser','Pullover','Dress','Coat',
               'Sandal','Shirt','Sneaker','Bag','Ankle boot']
print(f"Train: {x_train_full.shape} | Test: {x_test_full.shape}")
print(f"Classes: {CLASS_NAMES}")


# ---------- DATA SUBSET ----------
def prepare_subset(x_train, y_train, x_test, y_test,
                   train_size=52500, val_size=7500, seed=42):
    """Val diambil dari training — tidak menyentuh test set."""
    rng   = np.random.default_rng(seed)
    total = min(train_size + val_size, len(x_train))
    perm  = rng.permutation(len(x_train))[:total]
    x_tr  = x_train[perm[:train_size]];  y_tr  = y_train[perm[:train_size]]
    x_val = x_train[perm[train_size:]];  y_val = y_train[perm[train_size:]]
    return (x_tr, y_tr), (x_val, y_val), (x_test.copy(), y_test.copy())

(x_train, y_train), (x_val, y_val), (x_test, y_test) = prepare_subset(
    x_train_full, y_train_full, x_test_full, y_test_full
)
print(f"Train: {x_train.shape} | Val: {x_val.shape} | Test: {x_test.shape}")


# ---------- AUGMENTATION PIPELINE ----------
@tf.function
def augment(image, label):
    """
    Augmentasi untuk Fashion-MNIST:
    - random_flip_left_right: AMAN — baju/tas/sepatu simetris horizontal
    - random_brightness ringan: variasi pencahayaan kain/tekstur
    - random_contrast ringan: variasi kontras tekstur pakaian
    - padding + random_crop: simulasi translasi ±2px
    """
    image = tf.image.random_flip_left_right(image)      # AMAN untuk fashion
    image = tf.pad(image, [[3, 3], [3, 3], [0, 0]], mode='REFLECT')  # pad 3px
    image = tf.image.random_crop(image, size=[28, 28, 1])
    image = tf.image.random_brightness(image, max_delta=0.15)         # lebih kuat
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)    # lebih kuat
    return tf.clip_by_value(image, 0.0, 1.0), label

def mixup_batch(images, labels, alpha=0.3, num_classes=10):
    """
    Mixup augmentation: interpolasi antar gambar dalam batch.
    Membantu model belajar decision boundary Shirt vs T-shirt vs Coat.
    alpha=0.3 → campuran lebih kuat dari default 0.2
    """
    batch_size = tf.shape(images)[0]
    lam = tf.random.uniform([], 0.0, alpha)
    idx = tf.random.shuffle(tf.range(batch_size))

    mixed_x  = lam * images + (1.0 - lam) * tf.gather(images, idx)
    labels_oh = tf.one_hot(tf.cast(tf.reshape(labels, [-1]), tf.int32), num_classes)
    mixed_y   = lam * labels_oh + (1.0 - lam) * tf.gather(labels_oh, idx)
    return mixed_x, mixed_y


def make_dataset(x, y, batch_size, augment_data=False,
                 shuffle=True, use_mixup=False, num_classes=10):
    ds = tf.data.Dataset.from_tensor_slices((x, y))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(x), seed=42)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)
    if use_mixup:
        # Mixup diterapkan per-batch setelah augmentasi
        ds = ds.map(lambda x, y: mixup_batch(x, y, alpha=0.3,
                    num_classes=num_classes),
                    num_parallel_calls=tf.data.AUTOTUNE)
    return ds.prefetch(tf.data.AUTOTUNE)


# ---------- CNN BUILDER ----------
def se_block(x, ratio=4):
    """
    Squeeze-and-Excitation block — channel attention ringan.
    Membantu model fokus ke channel penting, terutama untuk
    membedakan kelas yang mirip (Shirt vs T-shirt vs Coat).
    """
    filters = x.shape[-1]
    se = tf.keras.layers.GlobalAveragePooling2D()(x)
    se = tf.keras.layers.Reshape((1, 1, filters))(se)
    se = tf.keras.layers.Dense(max(1, filters // ratio),
                                activation='relu', use_bias=False)(se)
    se = tf.keras.layers.Dense(filters,
                                activation='sigmoid', use_bias=False)(se)
    return tf.keras.layers.Multiply()([x, se])


def build_cnn_model(hp: dict, num_classes=10):
    """
    CNN dengan SE block untuk Fashion-MNIST.
    num_layers max 4: 28→14→7→4→2 (layer ke-5 → 1×1, tidak berguna)
    SE block membantu diferensiasi kelas visual yang mirip.
    """
    num_layers   = int(np.clip(hp['num_layers'],   2, 4))
    filters_base = int(np.clip(hp['filters_base'], 16,  64))  # FIX: naik ke 64
    dropout_rate = float(np.clip(hp['dropout_rate'], 0.2, 0.5))
    dense_units  = int(np.clip(hp['dense_units'],  64,  256))  # FIX: naik ke 256
    use_residual  = int(hp.get('use_residual',  0)) == 1
    use_separable = int(hp.get('use_separable', 0)) == 1

    inputs = tf.keras.Input(shape=(28, 28, 1))
    x = inputs

    for i in range(num_layers):
        filters  = min(filters_base * (2 ** i), 256)  # FIX: cap 256
        shortcut = x

        # Conv block 1
        if use_separable:
            x = tf.keras.layers.SeparableConv2D(
                    filters, 3, padding='same', use_bias=False,
                    depthwise_regularizer=tf.keras.regularizers.l2(1e-4),
                    pointwise_regularizer=tf.keras.regularizers.l2(1e-4))(x)
        else:
            x = tf.keras.layers.Conv2D(
                    filters, 3, padding='same', use_bias=False,
                    kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation('relu')(x)

        # Conv block 2
        if use_separable:
            x = tf.keras.layers.SeparableConv2D(
                    filters, 3, padding='same', use_bias=False,
                    depthwise_regularizer=tf.keras.regularizers.l2(1e-4),
                    pointwise_regularizer=tf.keras.regularizers.l2(1e-4))(x)
        else:
            x = tf.keras.layers.Conv2D(
                    filters, 3, padding='same', use_bias=False,
                    kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation('relu')(x)

        # SE block: channel attention
        x = se_block(x, ratio=4)

        # Residual connection
        if use_residual:
            if shortcut.shape[-1] != filters:
                shortcut = tf.keras.layers.Conv2D(
                    filters, 1, padding='same', use_bias=False)(shortcut)
                shortcut = tf.keras.layers.BatchNormalization()(shortcut)
            x = tf.keras.layers.add([x, shortcut])

        x = tf.keras.layers.MaxPooling2D(2, padding='same')(x)
        x = tf.keras.layers.Dropout(dropout_rate)(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(dense_units, use_bias=False,
                               kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    return tf.keras.Model(inputs, outputs)


# ---------- COSINE DECAY CALLBACK ----------
class CosineDecayCallback(tf.keras.callbacks.Callback):
    def __init__(self, lr_start, total_steps):
        super().__init__()
        self.lr_start = lr_start; self.total_steps = total_steps; self.step = 0

    def on_train_batch_end(self, batch, logs=None):
        self.step += 1
        frac   = self.step / self.total_steps
        new_lr = max(self.lr_start * 0.5 * (1 + np.cos(np.pi * frac)), 1e-6)
        self.model.optimizer.learning_rate.assign(new_lr)


# ---------- EVALUATION FUNCTION ----------
def evaluate_multi(lion, x_train, y_train, x_val, y_val,
                   epochs=15, verbose=0):
    hp         = lion.hyperparameters
    batch_size = int(np.clip(hp['batch_size'], 32, 128))
    model      = build_cnn_model(hp)
    initial_lr = float(hp['learning_rate'])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_lr),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    steps_per_epoch = max(1, len(x_train) // batch_size)
    total_steps     = steps_per_epoch * epochs
    train_ds = make_dataset(x_train, y_train, batch_size,
                             augment_data=True, use_mixup=False)
    val_ds   = make_dataset(x_val, y_val, batch_size,
                             augment_data=False, use_mixup=False, shuffle=False)

    try:
        t0 = time.time()
        history = model.fit(
            train_ds, epochs=epochs, validation_data=val_ds,
            callbacks=[
                tf.keras.callbacks.EarlyStopping(
                    monitor='val_accuracy', patience=8,
                    restore_best_weights=True, verbose=0),
                CosineDecayCallback(lr_start=initial_lr, total_steps=total_steps)
            ],
            verbose=verbose
        )
        train_time = time.time() - t0
        val_acc = max(history.history['val_accuracy'])
    except Exception as e:
        print(f"    ⚠ Training error: {e}")
        del model; gc.collect(); tf.keras.backend.clear_session()
        return {'accuracy':0.0,'inference_time':999.0,'model_size':999.0,'train_time':0.0}

    n_inf   = min(500, len(x_val))
    inf_idx = np.random.choice(len(x_val), n_inf, replace=False)
    t1 = time.time()
    model.predict(x_val[inf_idx], verbose=0)
    inf_time = (time.time() - t1) / n_inf * 1000

    model_size = model.count_params() * 4 / (1024**2)
    del model; gc.collect(); tf.keras.backend.clear_session()

    return {'accuracy':float(val_acc), 'inference_time':float(inf_time),
            'model_size':float(model_size), 'train_time':float(train_time)}


# ---------- NORMALISASI & DOMINANCE ----------
GLOBAL_NORM_BOUNDS = {
    'accuracy':       (0.0,   1.0),
    'inference_time': (0.0, 200.0),
    'model_size':     (0.0, 500.0),
}

def normalize_objectives(pop_fit):
    if not pop_fit: return pop_fit
    for p in pop_fit:
        for k in ['accuracy','inference_time','model_size']:
            mn, mx = GLOBAL_NORM_BOUNDS[k]
            raw = float(np.clip(p[k], mn, mx))
            p[k+'_norm'] = (raw-mn)/(mx-mn) if mx!=mn else 0.5
    return pop_fit

def dominates(a, b):
    av = (-a['accuracy_norm'], a['inference_time_norm'], a['model_size_norm'])
    bv = (-b['accuracy_norm'], b['inference_time_norm'], b['model_size_norm'])
    return all(x<=y for x,y in zip(av,bv)) and any(x<y for x,y in zip(av,bv))

def fast_non_dominated_sort(pop):
    if not pop: return []
    n = len(pop)
    dc = [0]*n; dl = [[] for _ in range(n)]; fronts = [[]]
    for i in range(n):
        for j in range(n):
            if i==j: continue
            if dominates(pop[i],pop[j]):   dl[i].append(j)
            elif dominates(pop[j],pop[i]): dc[i]+=1
        if dc[i]==0: fronts[0].append(i)
    i=0
    while i<len(fronts) and fronts[i]:
        nf=[]
        for idx in fronts[i]:
            for j in dl[idx]:
                dc[j]-=1
                if dc[j]==0: nf.append(j)
        if nf: fronts.append(nf)
        i+=1
    return [[pop[idx] for idx in f] for f in fronts if f]

def crowding_distance(front):
    n=len(front)
    if n<=2: return [float('inf')]*n
    dists=[0.0]*n
    for obj in ['accuracy_norm','inference_time_norm','model_size_norm']:
        sidx=sorted(range(n), key=lambda x: front[x][obj])
        dists[sidx[0]]=dists[sidx[-1]]=float('inf')
        span=front[sidx[-1]][obj]-front[sidx[0]][obj]
        if span==0: continue
        for k in range(1,n-1):
            dists[sidx[k]]+=(front[sidx[k+1]][obj]-front[sidx[k-1]][obj])/span
    return dists


# ---------- CLASS LION ----------
class Lion:
    def __init__(self, hyperparameters):
        self.hyperparameters = hyperparameters.copy()


# ---------- NS-LSO OPTIMIZER ----------
class NSLSO_Optimizer:
    def __init__(self, population_size=10, max_generations=6, hp_range=None):
        self.pop_size = population_size
        self.max_gen  = max_generations
        self.hp_range = hp_range or {
            'learning_rate': (1e-4, 3e-3),
            'batch_size':    (32,  128),
            'num_layers':    (2,   4),
            'filters_base':  (16,  64),   # FIX: kapasitas lebih besar
            'dropout_rate':  (0.2, 0.5),
            'dense_units':   (64,  256),  # FIX: dense lebih besar
            'use_residual':  (0,   1),
            'use_separable': (0,   1)
        }
        self.swarm=[]; self.archive=[]; self.history=[]

    def initialize(self):
        rng=np.random.default_rng(42); self.swarm=[]
        for _ in range(self.pop_size):
            hp={}
            for param,(low,high) in self.hp_range.items():
                if param=='learning_rate':
                    hp[param]=float(10**rng.uniform(np.log10(low),np.log10(high)))
                elif param in ['num_layers','batch_size','filters_base','dense_units',
                               'use_residual','use_separable']:
                    hp[param]=int(rng.integers(low,high+1))
                else:
                    hp[param]=float(rng.uniform(low,high))
            hp['momentum_lr']=0.0; hp['last_acc']=0.0
            self.swarm.append(Lion(hp))

    def lion_update(self, lion, archive, beta=0.9, eta=0.1):
        hp=lion.hyperparameters.copy()
        mean_acc=np.mean([p['accuracy'] for p in archive]) if archive else 0.5
        grad=(hp.get('last_acc',0.5)-mean_acc)/(mean_acc+1e-8)
        mom=beta*hp.get('momentum_lr',0.0)+(1-beta)*grad
        hp['momentum_lr']=float(mom)
        hp['learning_rate']=float(np.clip(
            hp['learning_rate']*(1+eta*np.sign(mom+1e-8)),1e-5,1e-2))

        if np.random.rand()<0.3:
            hp['num_layers']=int(np.clip(
                hp['num_layers']+np.random.choice([-1,1]),2,4))

        for param in ['filters_base','dense_units']:
            if np.random.rand()<0.3:
                low,high=self.hp_range[param]
                hp[param]=int(np.clip(int(hp[param]*np.random.uniform(0.85,1.15)),low,high))

        if np.random.rand()<0.3:
            choices=[32,64,128,256]
            idx=min(range(len(choices)),key=lambda x: abs(choices[x]-int(hp['batch_size'])))
            hp['batch_size']=choices[int(np.clip(idx+np.random.choice([-1,1]),0,len(choices)-1))]

        if np.random.rand()<0.3:
            hp['dropout_rate']=float(np.clip(
                hp['dropout_rate']+np.random.normal(0,0.05),0.0,0.5))

        if np.random.rand()<0.2: hp['use_residual'] =1-int(hp.get('use_residual', 0))
        if np.random.rand()<0.2: hp['use_separable']=1-int(hp.get('use_separable',0))

        return Lion(hp)

    def optimize(self, x_train, y_train, x_val, y_val,
                 epochs_per_eval=15, verbose=1):
        self.initialize()
        # FIX: Elitisme — simpan best Lion agar tidak hilang antar generasi
        best_elite    = None
        best_elite_acc = 0.0
        for gen in range(1, self.max_gen+1):
            if verbose:
                print(f"\n{'='*60}"); print(f"GENERATION {gen}/{self.max_gen}"); print(f"{'='*60}")

            pop_fit=[]
            for i,lion in enumerate(self.swarm):
                fit=evaluate_multi(lion,x_train,y_train,x_val,y_val,
                                   epochs=epochs_per_eval,verbose=0)
                lion.hyperparameters['last_acc']=fit['accuracy']

                if fit['accuracy']<0.15:
                    if verbose: print(f"  Lion {i+1:2d}: FAILED (acc={fit['accuracy']:.4f})")
                    continue

                fit['hyperparams']={k:v for k,v in lion.hyperparameters.items()
                                    if not k.startswith('momentum') and k!='last_acc'}
                pop_fit.append(fit)
                # Update elite
                if fit['accuracy'] > best_elite_acc:
                    best_elite_acc = fit['accuracy']
                    best_elite     = fit.copy()
                if verbose:
                    print(f"  Lion {i+1:2d}/{self.pop_size}: "
                          f"acc={fit['accuracy']:.4f} | "
                          f"inf={fit['inference_time']:.2f}ms | "
                          f"size={fit['model_size']:.2f}MB")

            if not pop_fit:
                print("  ⚠ All failed! Using backup...")
                fit=evaluate_multi(self.swarm[0],x_train,y_train,x_val,y_val,epochs=15)
                fit['hyperparams']={k:v for k,v in self.swarm[0].hyperparameters.items()
                                    if not k.startswith('momentum') and k!='last_acc'}
                fit['accuracy']=max(fit['accuracy'],0.15); pop_fit.append(fit)

            pop_fit      =normalize_objectives(pop_fit)
            self.archive =normalize_objectives(self.archive)
            fronts       =fast_non_dominated_sort(pop_fit+self.archive)

            new_archive=[]
            for front in fronts:
                if len(new_archive)+len(front)<=self.pop_size:
                    new_archive.extend(front)
                else:
                    cd=crowding_distance(front)
                    ranked=sorted(zip(cd,front),key=lambda x:x[0],reverse=True)
                    new_archive.extend(s for _,s in ranked[:self.pop_size-len(new_archive)])
                    break
            self.archive=new_archive

            front_0=fronts[0] if fronts else []
            print(f"\n  >>> FRONT-0: {len(front_0)} solutions <<<")
            for sol in front_0[:3]:
                print(f"      acc={sol['accuracy']:.4f} | "
                      f"inf={sol['inference_time']:.2f}ms | "
                      f"size={sol['model_size']:.2f}MB")

            self.swarm=[self.lion_update(lion,self.archive) for lion in self.swarm]
            # FIX Elitisme: ganti lion terakhir dengan elite terbaik
            if best_elite:
                elite_lion = Lion(best_elite['hyperparams'])
                self.swarm[-1] = elite_lion
            self.history.append({'generation':gen,'front_0_size':len(front_0),
                                 'archive_size':len(self.archive),
                                 'best_acc':max((s['accuracy'] for s in self.archive),default=0.0)})
            if gen%2==0: self._save_checkpoint(f'/kaggle/working/nslso_checkpoint_gen{gen}.json')

        return self.archive

    def _save_checkpoint(self, path):
        def _cast(v):
            if isinstance(v,(np.floating,float)): return float(v)
            if isinstance(v,(np.integer,int)):     return int(v)
            if isinstance(v,np.ndarray):           return v.tolist()
            return v
        with open(path,'w') as f:
            json.dump({'archive':[{k:_cast(v) for k,v in s.items() if k!='hyperparams'}
                                  for s in self.archive],'history':self.history},f,indent=2)
        print(f"  [✓] Checkpoint saved: {path}")


# ---------- FINAL EVALUATION ----------
def final_test_evaluation(best_hp, x_train_full, y_train_full,
                          x_test, y_test, epochs=200):  # FIX: dari 150
    """
    FIX v4 — Perbaikan bug akurasi test 10.26%:
    ROOT CAUSE: make_dataset mengembalikan integer label, tapi model
    dilatih dengan categorical_crossentropy (one-hot). Prediksi test
    set via make_dataset menyebabkan argmax tidak bisa dibandingkan
    dengan benar → semua prediksi salah → akurasi ~10% (random).

    SOLUSI: Prediksi test set LANGSUNG dari numpy x_test, bukan
    lewat make_dataset. Output softmax → argmax → integer,
    dibandingkan dengan y_test integer → accuracy_score benar.

    Perubahan lain:
    - patience=20 (dari 10) — cegah early stop terlalu dini
    - epochs=150 (dari 100) — ruang belajar lebih banyak
    - SE block + Mixup tetap aktif
    """
    rng=np.random.default_rng(99); n=len(x_train_full)
    perm=rng.permutation(n); cut=int(n*0.9)
    x_tr=x_train_full[perm[:cut]];   y_tr=y_train_full[perm[:cut]]
    x_vl=x_train_full[perm[cut:]];   y_vl=y_train_full[perm[cut:]]

    batch_size=int(np.clip(best_hp['batch_size'],32,128))
    model=build_cnn_model(best_hp)
    initial_lr=float(best_hp['learning_rate'])

    # FIX 3a: Pakai CategoricalCrossentropy karena mixup menghasilkan soft labels
    # Tidak pakai label smoothing — agar val_accuracy tetap representatif
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=initial_lr),
        loss='categorical_crossentropy',   # cocok untuk one-hot (mixup output)
        metrics=['accuracy']
    )

    steps_total=max(1,len(x_tr)//batch_size)*epochs

    # FIX 3b: Mixup aktif di training — val TIDAK pakai mixup agar akurasi valid
    train_ds=make_dataset(x_tr, y_tr, batch_size,
                          augment_data=True, use_mixup=True, num_classes=10)
    val_ds  =make_dataset(x_vl, y_vl, batch_size,
                          augment_data=False, use_mixup=False, num_classes=10)
    # Val perlu one-hot juga karena loss = CategoricalCrossentropy
    val_ds = val_ds.map(lambda x, y: (
        x, tf.one_hot(tf.cast(tf.reshape(y, [-1]), tf.int32), 10)
    ))

    # FIX: Warmup 5 epoch lalu cosine decay — lebih stabil dari pure cosine
    warmup_steps = max(1, len(x_tr) // batch_size) * 5

    class WarmupCosineDecay(tf.keras.callbacks.Callback):
        def __init__(self, lr_s, total, warmup):
            super().__init__()
            self.lr_s=lr_s; self.total=total; self.warmup=warmup; self.step=0
        def on_train_batch_end(self, batch, logs=None):
            self.step += 1
            if self.step < self.warmup:
                new_lr = self.lr_s * (self.step / self.warmup)
            else:
                frac   = (self.step-self.warmup)/(self.total-self.warmup+1e-8)
                new_lr = max(self.lr_s*0.5*(1+np.cos(np.pi*frac)),1e-7)
            self.model.optimizer.learning_rate.assign(new_lr)

    print(f"\nTraining final model ({epochs} epochs, Mixup + SE + Warmup LR)...")
    history=model.fit(
        train_ds,epochs=epochs,validation_data=val_ds,
        callbacks=[
            # FIX 3c: patience 10→20 — cegah early stop terlalu dini
            tf.keras.callbacks.EarlyStopping(
                monitor='val_accuracy', patience=30,  # FIX: dari 20
                restore_best_weights=True, verbose=1),
            CosineDecayCallback(lr_start=initial_lr, total_steps=steps_total)
        ],verbose=1
    )

    # FIX KRITIS: Prediksi LANGSUNG dari numpy array x_test
    # Jangan pakai make_dataset — hindari ambiguitas format label
    # Model output: softmax 10 kelas → argmax → integer 0-9
    # y_test sudah integer → accuracy_score benar
    y_pred_probs = model.predict(x_test, batch_size=batch_size, verbose=0)
    y_pred       = np.argmax(y_pred_probs, axis=1)
    # y_test adalah integer (0-9), y_pred juga integer → kompatibel

    # Semua metrik
    accuracy          =accuracy_score(y_test,y_pred)
    precision_pc      =precision_score(y_test,y_pred,average=None,zero_division=0)
    recall_pc         =recall_score(y_test,y_pred,average=None,zero_division=0)
    f1_pc             =f1_score(y_test,y_pred,average=None,zero_division=0)
    precision_macro   =float(np.mean(precision_pc))
    recall_macro      =float(np.mean(recall_pc))
    f1_macro          =float(np.mean(f1_pc))
    precision_weighted=float(precision_score(y_test,y_pred,average='weighted',zero_division=0))
    recall_weighted   =float(recall_score(y_test,y_pred,average='weighted',zero_division=0))
    f1_weighted       =float(f1_score(y_test,y_pred,average='weighted',zero_division=0))

    cm    =confusion_matrix(y_test,y_pred)
    cm_pct=cm/cm.sum(axis=1,keepdims=True)*100

    model_size  =model.count_params()*4/(1024**2)
    total_params=model.count_params()

    # Inference time: numpy langsung, bukan tf.data
    n_inf   = min(500, len(x_test))
    inf_idx = np.random.choice(len(x_test), n_inf, replace=False)
    t1 = time.time()
    model.predict(x_test[inf_idx], batch_size=batch_size, verbose=0)
    inf_time = (time.time() - t1) / n_inf * 1000

    model.save('/kaggle/working/best_fashion_model.keras')
    print("[✓] Model saved: /kaggle/working/best_fashion_model.keras")

    del model; gc.collect(); tf.keras.backend.clear_session()
    return {
        'accuracy':accuracy,
        'precision_per_class':precision_pc.tolist(),
        'recall_per_class':recall_pc.tolist(),
        'f1_per_class':f1_pc.tolist(),
        'precision_macro':precision_macro,'recall_macro':recall_macro,'f1_macro':f1_macro,
        'precision_weighted':precision_weighted,'recall_weighted':recall_weighted,'f1_weighted':f1_weighted,
        'confusion_matrix':cm.tolist(),'confusion_matrix_percent':cm_pct.tolist(),
        'inference_time_ms':float(inf_time),'model_size_mb':float(model_size),
        'total_params':int(total_params),'y_pred':y_pred.tolist()
    }, history


# ---------- MAIN ----------
def main():
    print("\n"+"="*60)
    print("NS-LSO: Multi-Objective CNN Optimization — Fashion-MNIST")
    print("="*60)

    nslso=NSLSO_Optimizer(
        population_size=5,max_generations=15,  # FIX: dari 10
        hp_range={
            'learning_rate':(1e-4, 3e-3),
            'batch_size'   :(32,  128),
            'num_layers'   :(2,   4),
            'filters_base' :(16,  64),   # FIX: kapasitas naik
            'dropout_rate' :(0.2, 0.5),
            'dense_units'  :(64,  256),  # FIX: dense naik
            'use_residual' :(0,   1),
            'use_separable':(0,   1)
        }
    )

    start=time.time()
    pareto_front=nslso.optimize(x_train,y_train,x_val,y_val,
                                epochs_per_eval=15,verbose=1)
    total_time=time.time()-start

    print("\n"+"="*60); print("FINAL RESULTS"); print("="*60)
    print(f"Total time   : {total_time/3600:.2f} hours")
    print(f"Pareto-front : {len(pareto_front)} solutions")

    pareto_front.sort(key=lambda x: x['accuracy'],reverse=True)
    print("\n--- TOP 5 PARETO SOLUTIONS ---")
    for i,sol in enumerate(pareto_front[:5],1):
        hp=sol['hyperparams']
        print(f"\n  Solution {i}: acc={sol['accuracy']:.4f} | "
              f"inf={sol['inference_time']:.2f}ms | size={sol['model_size']:.2f}MB")
        print(f"    lr={hp['learning_rate']:.5f}, layers={hp['num_layers']}, "
              f"filters={hp['filters_base']}, batch={hp['batch_size']}, "
              f"dense={hp['dense_units']}, dropout={hp['dropout_rate']:.2f}, "
              f"residual={hp['use_residual']}, separable={hp['use_separable']}")

    # Final evaluation
    print("\n"+"="*60); print("FINAL EVALUATION ON TEST SET"); print("="*60)
    best_hp=pareto_front[0]['hyperparams']
    print(f"\nBest solution val acc : {pareto_front[0]['accuracy']:.4f}")

    results, history = final_test_evaluation(
        best_hp, x_train_full, y_train_full, x_test_full, y_test_full, epochs=200
    )

    # Print semua metrik
    print("\n"+"="*60); print("TEST SET METRICS"); print("="*60)
    print(f"\n  Accuracy           : {results['accuracy']:.4f} ({results['accuracy']*100:.2f}%)")
    print(f"  Precision (macro)  : {results['precision_macro']:.4f}")
    print(f"  Recall (macro)     : {results['recall_macro']:.4f}")
    print(f"  F1-score (macro)   : {results['f1_macro']:.4f}")
    print(f"  Precision (weighted): {results['precision_weighted']:.4f}")
    print(f"  Recall (weighted)  : {results['recall_weighted']:.4f}")
    print(f"  F1 (weighted)      : {results['f1_weighted']:.4f}")

    print("\n  --- Per-class metrics ---")
    print(f"  {'Kelas':<16} {'Precision':>10} {'Recall':>8} {'F1':>8}")
    print("  " + "-"*37)
    for i in range(10):
        print(f"  {i} {CLASS_NAMES[i]:<14}  {results['precision_per_class'][i]:.4f}   "
              f"{results['recall_per_class'][i]:.4f}   {results['f1_per_class'][i]:.4f}")

    print(f"\n  Inference time : {results['inference_time_ms']:.3f} ms/gambar")
    print(f"  Model size     : {results['model_size_mb']:.2f} MB")
    print(f"  Total params   : {results['total_params']:,}")

    # Confusion matrix
    fig, axes = plt.subplots(1, 2, figsize=(18, 7))
    cm    = np.array(results['confusion_matrix'])
    cm_pct= np.array(results['confusion_matrix_percent'])
    sns.heatmap(cm,    annot=True, fmt='d',   cmap='Blues',
                xticklabels=CLASS_NAMES,yticklabels=CLASS_NAMES,ax=axes[0])
    axes[0].set_title('Confusion Matrix — Fashion-MNIST (Count)')
    axes[0].set_xlabel('Predicted'); axes[0].set_ylabel('True')
    axes[0].tick_params(axis='x', rotation=45)
    axes[0].tick_params(axis='x', rotation=45)
    sns.heatmap(cm_pct,annot=True, fmt='.1f', cmap='Blues',
                xticklabels=CLASS_NAMES,yticklabels=CLASS_NAMES,ax=axes[1])
    axes[1].set_title('Confusion Matrix — Fashion-MNIST (%)')
    axes[1].set_xlabel('Predicted'); axes[1].set_ylabel('True')
    axes[1].tick_params(axis='x', rotation=45)
    axes[1].tick_params(axis='x', rotation=45)
    plt.tight_layout()
    plt.savefig('/kaggle/working/fashion_confusion_matrices.png',dpi=150,bbox_inches='tight')
    print("[✓] Confusion matrix saved")
    plt.show()

    # Training history
    fig, ax = plt.subplots(1, 2, figsize=(14, 5))
    ax[0].plot(history.history['accuracy'],     label='Train')
    ax[0].plot(history.history['val_accuracy'], label='Validation')
    ax[0].set(xlabel='Epoch',ylabel='Accuracy',title='Accuracy History — Fashion-MNIST')
    ax[0].legend(); ax[0].grid(alpha=0.3)
    ax[1].plot(history.history['loss'],     label='Train')
    ax[1].plot(history.history['val_loss'], label='Validation')
    ax[1].set(xlabel='Epoch',ylabel='Loss',title='Loss History — Fashion-MNIST')
    ax[1].legend(); ax[1].grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig('/kaggle/working/fashion_training_history.png',dpi=150,bbox_inches='tight')
    print("[✓] Training history saved")
    plt.show()

    # Pareto front
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    accs =[s['accuracy']       for s in pareto_front]
    infs =[s['inference_time'] for s in pareto_front]
    sizes=[s['model_size']     for s in pareto_front]
    axes[0].scatter(infs, accs, s=80,alpha=0.7,c='steelblue',edgecolors='k')
    axes[0].set(xlabel='Inference Time (ms)',ylabel='Val Accuracy',title='Accuracy vs Inference Time')
    axes[0].grid(alpha=0.3)
    axes[1].scatter(sizes,accs, s=80,alpha=0.7,c='seagreen',edgecolors='k')
    axes[1].set(xlabel='Model Size (MB)',ylabel='Val Accuracy',title='Accuracy vs Model Size')
    axes[1].grid(alpha=0.3)
    axes[2].plot([h['generation'] for h in nslso.history],
                 [h['best_acc']   for h in nslso.history],marker='o',color='tomato')
    axes[2].set(xlabel='Generation',ylabel='Best Val Accuracy',title='Convergence Curve')
    axes[2].grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig('/kaggle/working/fashion_pareto_front.png',dpi=150,bbox_inches='tight')
    print("[✓] Pareto front saved")
    plt.show()

    # Save JSON
    def _cast(v):
        if isinstance(v,(np.floating,float)): return float(v)
        if isinstance(v,(np.integer,int)):     return int(v)
        if isinstance(v,np.ndarray):           return v.tolist()
        return v

    with open('/kaggle/working/fashion_nslso_results.json','w') as f:
        json.dump({
            'pareto_front':[{k:_cast(v) for k,v in s.items() if k!='hyperparams'}
                            for s in pareto_front],
            'hyperparams':[s['hyperparams'] for s in pareto_front],
            'total_time_hours':total_time/3600,
            **{k:results[k] for k in ['accuracy','precision_macro','recall_macro',
                                       'f1_macro','precision_weighted','recall_weighted',
                                       'f1_weighted','precision_per_class','recall_per_class',
                                       'f1_per_class','inference_time_ms','model_size_mb',
                                       'total_params','confusion_matrix','confusion_matrix_percent']}
        },f,indent=2)
    print("[✓] All results saved: /kaggle/working/fashion_nslso_results.json")

    print("\n"+"="*60)
    print("NS-LSO FASHION-MNIST COMPLETED")
    print("="*60)
    return pareto_front, results

if __name__ == "__main__":
    pareto, results = main()
# Out:
# ✓ GPUs: 2
# ============================================================
# LOADING FASHION-MNIST DATASET
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train: (60000, 28, 28, 1) | Test: (10000, 28, 28, 1)
# Classes: ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# Train: (52500, 28, 28, 1) | Val: (7500, 28, 28, 1) | Test: (10000, 28, 28, 1)
#
# ============================================================
# NS-LSO: Multi-Objective CNN Optimization — Fashion-MNIST
# ============================================================
#
# ============================================================
# GENERATION 1/15
# ============================================================
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787401394.331708      22 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1787401394.335356      22 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# I0000 00:00:1787401415.295226      68 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   Lion  1/5: acc=0.9272 | inf=6.07ms | size=1.66MB
#   Lion  2/5: acc=0.9405 | inf=9.67ms | size=7.59MB
#   Lion  3/5: acc=0.9091 | inf=9.46ms | size=8.04MB
#   Lion  4/5: acc=0.8513 | inf=14.88ms | size=0.66MB
#   Lion  5/5: acc=0.8472 | inf=21.75ms | size=0.17MB
#
#   >>> FRONT-0: 4 solutions <<<
#       acc=0.9272 | inf=6.07ms | size=1.66MB
#       acc=0.9405 | inf=9.67ms | size=7.59MB
#       acc=0.8513 | inf=14.88ms | size=0.66MB
#
# ============================================================
# GENERATION 2/15
# ============================================================
#   Lion  1/5: acc=0.9288 | inf=4.31ms | size=1.66MB
#   Lion  2/5: acc=0.9369 | inf=5.60ms | size=3.17MB
#   Lion  3/5: acc=0.9143 | inf=5.44ms | size=3.52MB
#   Lion  4/5: acc=0.8421 | inf=6.59ms | size=0.66MB
#   Lion  5/5: acc=0.9356 | inf=6.78ms | size=7.59MB
#
#   >>> FRONT-0: 6 solutions <<<
#       acc=0.9288 | inf=4.31ms | size=1.66MB
#       acc=0.9369 | inf=5.60ms | size=3.17MB
#       acc=0.8421 | inf=6.59ms | size=0.66MB
#   [✓] Checkpoint saved: /kaggle/working/nslso_checkpoint_gen2.json
#
# ============================================================
# GENERATION 3/15
# ============================================================
#   Lion  1/5: acc=0.8984 | inf=17.27ms | size=1.04MB
#   Lion  2/5: acc=0.9377 | inf=7.30ms | size=7.60MB
#   Lion  3/5: acc=0.9157 | inf=5.35ms | size=3.15MB
#   Lion  4/5: acc=0.8175 | inf=14.07ms | size=0.49MB
#   Lion  5/5: acc=0.9361 | inf=7.00ms | size=7.59MB
#
#   >>> FRONT-0: 9 solutions <<<
#       acc=0.8984 | inf=17.27ms | size=1.04MB
#       acc=0.9377 | inf=7.30ms | size=7.60MB
#       acc=0.8175 | inf=14.07ms | size=0.49MB
#
# ============================================================
# GENERATION 4/15
# ============================================================
#   Lion  1/5: acc=0.9316 | inf=5.88ms | size=5.59MB
#   Lion  2/5: acc=0.9235 | inf=24.62ms | size=1.58MB
#   Lion  3/5: acc=0.8240 | inf=7.14ms | size=0.70MB
#   Lion  4/5: acc=0.7484 | inf=6.69ms | size=0.49MB
#   Lion  5/5: acc=0.9364 | inf=6.80ms | size=7.59MB
#
#   >>> FRONT-0: 10 solutions <<<
#       acc=0.9316 | inf=5.88ms | size=5.59MB
#       acc=0.9235 | inf=24.62ms | size=1.58MB
#       acc=0.8240 | inf=7.14ms | size=0.70MB
#   [✓] Checkpoint saved: /kaggle/working/nslso_checkpoint_gen4.json
#
# ============================================================
# GENERATION 5/15
# ============================================================
#   Lion  1/5: acc=0.9309 | inf=4.12ms | size=1.77MB
#   Lion  2/5: acc=0.9229 | inf=21.47ms | size=0.57MB
#   Lion  3/5: acc=0.8577 | inf=16.10ms | size=1.63MB
#   Lion  4/5: acc=0.8007 | inf=6.90ms | size=0.49MB
#   Lion  5/5: acc=0.9361 | inf=7.11ms | size=7.59MB
#
#   >>> FRONT-0: 10 solutions <<<
#       acc=0.9309 | inf=4.12ms | size=1.77MB
#       acc=0.9229 | inf=21.47ms | size=0.57MB
#       acc=0.8577 | inf=16.10ms | size=1.63MB
#
# ============================================================
# GENERATION 6/15
# ============================================================
#   Lion  1/5: acc=0.9319 | inf=5.10ms | size=1.28MB
#   Lion  2/5: acc=0.9191 | inf=8.61ms | size=1.25MB
#   Lion  3/5: acc=0.7865 | inf=8.57ms | size=1.62MB
#   Lion  4/5: acc=0.7823 | inf=6.61ms | size=0.49MB
#   Lion  5/5: acc=0.9375 | inf=6.77ms | size=7.59MB
#
#   >>> FRONT-0: 7 solutions <<<
#       acc=0.9319 | inf=5.10ms | size=1.28MB
#       acc=0.9191 | inf=8.61ms | size=1.25MB
#       acc=0.7823 | inf=6.61ms | size=0.49MB
#   [✓] Checkpoint saved: /kaggle/working/nslso_checkpoint_gen6.json
#
# ============================================================
# GENERATION 7/15
# ============================================================
#   Lion  1/5: acc=0.9307 | inf=4.17ms | size=1.28MB
#   Lion  2/5: acc=0.9211 | inf=8.73ms | size=1.25MB
#   Lion  3/5: acc=0.8477 | inf=8.41ms | size=1.62MB
#   Lion  4/5: acc=0.7436 | inf=9.85ms | size=1.40MB
#   Lion  5/5: acc=0.9379 | inf=6.88ms | size=7.59MB
#
#   >>> FRONT-0: 7 solutions <<<
#       acc=0.9307 | inf=4.17ms | size=1.28MB
#       acc=0.9211 | inf=8.73ms | size=1.25MB
#       acc=0.9379 | inf=6.88ms | size=7.59MB
#
# ============================================================
# GENERATION 8/15
# ============================================================
#   Lion  1/5: acc=0.9337 | inf=4.21ms | size=1.28MB
#   Lion  2/5: acc=0.9203 | inf=8.75ms | size=1.22MB
#   Lion  3/5: acc=0.9247 | inf=6.78ms | size=8.33MB
#   Lion  4/5: acc=0.7527 | inf=17.47ms | size=1.31MB
#   Lion  5/5: acc=0.9365 | inf=6.76ms | size=7.59MB
#
#   >>> FRONT-0: 8 solutions <<<
#       acc=0.9337 | inf=4.21ms | size=1.28MB
#       acc=0.9203 | inf=8.75ms | size=1.22MB
#       acc=0.9365 | inf=6.76ms | size=7.59MB
#   [✓] Checkpoint saved: /kaggle/working/nslso_checkpoint_gen8.json
#
# ============================================================
# GENERATION 9/15
# ============================================================
#   Lion  1/5: acc=0.9309 | inf=4.91ms | size=1.13MB
#   Lion  2/5: acc=0.9195 | inf=8.60ms | size=1.22MB
#   Lion  3/5: acc=0.9237 | inf=5.29ms | size=8.33MB
#   Lion  4/5: acc=0.8476 | inf=5.98ms | size=6.56MB
#   Lion  5/5: acc=0.9392 | inf=6.74ms | size=7.59MB
#
#   >>> FRONT-0: 5 solutions <<<
#       acc=0.9309 | inf=4.91ms | size=1.13MB
#       acc=0.9392 | inf=6.74ms | size=7.59MB
#       acc=0.7823 | inf=6.61ms | size=0.49MB
#
# ============================================================
# GENERATION 10/15
# ============================================================
#   Lion  1/5: acc=0.9269 | inf=5.09ms | size=0.87MB
#   Lion  2/5: acc=0.9156 | inf=14.00ms | size=0.50MB
#   Lion  3/5: acc=0.9017 | inf=7.05ms | size=8.70MB
#   Lion  4/5: acc=0.8348 | inf=5.55ms | size=6.56MB
#   Lion  5/5: acc=0.9365 | inf=6.86ms | size=7.59MB
#
#   >>> FRONT-0: 7 solutions <<<
#       acc=0.9269 | inf=5.09ms | size=0.87MB
#       acc=0.9156 | inf=14.00ms | size=0.50MB
#       acc=0.9309 | inf=4.91ms | size=1.13MB
#   [✓] Checkpoint saved: /kaggle/working/nslso_checkpoint_gen10.json
#
# ============================================================
# GENERATION 11/15
# ============================================================
#   Lion  1/5: acc=0.9236 | inf=4.95ms | size=0.81MB
#   Lion  2/5: acc=0.9073 | inf=5.55ms | size=0.17MB
#   Lion  3/5: acc=0.9056 | inf=6.90ms | size=8.70MB
#   Lion  4/5: acc=0.7601 | inf=6.72ms | size=6.84MB
#   Lion  5/5: acc=0.9393 | inf=6.92ms | size=7.59MB
#
#   >>> FRONT-0: 6 solutions <<<
#       acc=0.9236 | inf=4.95ms | size=0.81MB
#       acc=0.9073 | inf=5.55ms | size=0.17MB
#       acc=0.9393 | inf=6.92ms | size=7.59MB
#
# ============================================================
# GENERATION 12/15
# ============================================================
#   Lion  1/5: acc=0.9163 | inf=5.50ms | size=0.83MB
#   Lion  2/5: acc=0.9071 | inf=5.73ms | size=0.17MB
#   Lion  3/5: acc=0.8916 | inf=7.06ms | size=8.70MB
#   Lion  4/5: acc=0.7965 | inf=5.42ms | size=1.92MB
#   Lion  5/5: acc=0.9383 | inf=7.08ms | size=7.59MB
#
#   >>> FRONT-0: 6 solutions <<<
#       acc=0.9163 | inf=5.50ms | size=0.83MB
#       acc=0.9073 | inf=5.55ms | size=0.17MB
#       acc=0.9393 | inf=6.92ms | size=7.59MB
#   [✓] Checkpoint saved: /kaggle/working/nslso_checkpoint_gen12.json
#
# ============================================================
# GENERATION 13/15
# ============================================================
#   Lion  1/5: acc=0.9244 | inf=4.26ms | size=0.81MB
#   Lion  2/5: acc=0.9189 | inf=6.54ms | size=0.41MB
#   Lion  3/5: acc=0.8805 | inf=6.83ms | size=9.52MB
#   Lion  4/5: acc=0.6388 | inf=4.57ms | size=0.49MB
#   Lion  5/5: acc=0.9396 | inf=6.80ms | size=7.59MB
#
#   >>> FRONT-0: 7 solutions <<<
#       acc=0.9244 | inf=4.26ms | size=0.81MB
#       acc=0.9189 | inf=6.54ms | size=0.41MB
#       acc=0.6388 | inf=4.57ms | size=0.49MB
#
# ============================================================
# GENERATION 14/15
# ============================================================
#   Lion  1/5: acc=0.9191 | inf=5.56ms | size=3.05MB
#   Lion  2/5: acc=0.9256 | inf=5.83ms | size=5.77MB
#   Lion  3/5: acc=0.8825 | inf=6.08ms | size=9.52MB
#   Lion  4/5: acc=0.7441 | inf=5.80ms | size=2.09MB
#   Lion  5/5: acc=0.9399 | inf=6.77ms | size=7.59MB
#
#   >>> FRONT-0: 5 solutions <<<
#       acc=0.9399 | inf=6.77ms | size=7.59MB
#       acc=0.6388 | inf=4.57ms | size=0.49MB
#       acc=0.9073 | inf=5.55ms | size=0.17MB
#   [✓] Checkpoint saved: /kaggle/working/nslso_checkpoint_gen14.json
#
# ============================================================
# GENERATION 15/15
# ============================================================
#   Lion  1/5: acc=0.9172 | inf=4.29ms | size=0.79MB
#   Lion  2/5: acc=0.9233 | inf=5.28ms | size=5.78MB
#   Lion  3/5: acc=0.8727 | inf=6.00ms | size=9.50MB
#   Lion  4/5: acc=0.7012 | inf=5.49ms | size=2.09MB
#   Lion  5/5: acc=0.9412 | inf=6.93ms | size=7.59MB
#
#   >>> FRONT-0: 7 solutions <<<
#       acc=0.9172 | inf=4.29ms | size=0.79MB
#       acc=0.9412 | inf=6.93ms | size=7.59MB
#       acc=0.9399 | inf=6.77ms | size=7.59MB
#
# ============================================================
# FINAL RESULTS
# ============================================================
# Total time   : 4.69 hours
# Pareto-front : 5 solutions
#
# --- TOP 5 PARETO SOLUTIONS ---
#
#   Solution 1: acc=0.9412 | inf=6.93ms | size=7.59MB
#     lr=0.00276, layers=4, filters=51, batch=103, dense=215, dropout=0.24, residual=1, separable=0
#
#   Solution 2: acc=0.9392 | inf=6.74ms | size=7.59MB
#     lr=0.00276, layers=4, filters=51, batch=103, dense=215, dropout=0.24, residual=1, separable=0
#
#   Solution 3: acc=0.9309 | inf=4.12ms | size=1.77MB
#     lr=0.00204, layers=3, filters=38, batch=64, dense=256, dropout=0.37, residual=0, separable=0
#
#   Solution 4: acc=0.9073 | inf=5.55ms | size=0.17MB
#     lr=0.00716, layers=2, filters=40, batch=32, dense=233, dropout=0.12, residual=1, separable=1
#
#   Solution 5: acc=0.6388 | inf=4.57ms | size=0.49MB
#     lr=0.00006, layers=2, filters=42, batch=128, dense=81, dropout=0.36, residual=1, separable=0
#
# ============================================================
# FINAL EVALUATION ON TEST SET
# ============================================================
#
# Best solution val acc : 0.9412
#
# Training final model (200 epochs, Mixup + SE + Warmup LR)...
# Epoch 1/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 59s 69ms/step - accuracy: 0.7074 - loss: 1.3745 - val_accuracy: 0.8112 - val_loss: 0.7145
# Epoch 2/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 32ms/step - accuracy: 0.7959 - loss: 1.1357 - val_accuracy: 0.7815 - val_loss: 0.7613
# Epoch 3/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 32ms/step - accuracy: 0.8085 - loss: 1.1193 - val_accuracy: 0.8535 - val_loss: 0.6327
# Epoch 4/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8201 - loss: 1.0936 - val_accuracy: 0.8655 - val_loss: 0.5691
# Epoch 5/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8257 - loss: 1.0595 - val_accuracy: 0.8742 - val_loss: 0.6012
# Epoch 6/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8307 - loss: 1.0354 - val_accuracy: 0.8503 - val_loss: 0.6019
# Epoch 7/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 32ms/step - accuracy: 0.8374 - loss: 1.0246 - val_accuracy: 0.8762 - val_loss: 0.5213
# Epoch 8/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8363 - loss: 1.0265 - val_accuracy: 0.8765 - val_loss: 0.5310
# Epoch 9/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8407 - loss: 0.9990 - val_accuracy: 0.8992 - val_loss: 0.4923
# Epoch 10/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8463 - loss: 0.9886 - val_accuracy: 0.9022 - val_loss: 0.4693
# Epoch 11/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8466 - loss: 0.9896 - val_accuracy: 0.8902 - val_loss: 0.5256
# Epoch 12/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8481 - loss: 0.9678 - val_accuracy: 0.8720 - val_loss: 0.5282
# Epoch 13/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8503 - loss: 0.9615 - val_accuracy: 0.8820 - val_loss: 0.5153
# Epoch 14/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8538 - loss: 0.9522 - val_accuracy: 0.8858 - val_loss: 0.5137
# Epoch 15/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8562 - loss: 0.9339 - val_accuracy: 0.9008 - val_loss: 0.4530
# Epoch 16/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8582 - loss: 0.9323 - val_accuracy: 0.9097 - val_loss: 0.4593
# Epoch 17/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8571 - loss: 0.9304 - val_accuracy: 0.8938 - val_loss: 0.4778
# Epoch 18/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8575 - loss: 0.9297 - val_accuracy: 0.8952 - val_loss: 0.4599
# Epoch 19/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8577 - loss: 0.9293 - val_accuracy: 0.8833 - val_loss: 0.4980
# Epoch 20/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8597 - loss: 0.9307 - val_accuracy: 0.9077 - val_loss: 0.4227
# Epoch 21/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8599 - loss: 0.9216 - val_accuracy: 0.9068 - val_loss: 0.4599
# Epoch 22/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8619 - loss: 0.9194 - val_accuracy: 0.9082 - val_loss: 0.4191
# Epoch 23/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8653 - loss: 0.9044 - val_accuracy: 0.8882 - val_loss: 0.4451
# Epoch 24/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8632 - loss: 0.9182 - val_accuracy: 0.9030 - val_loss: 0.4318
# Epoch 25/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8643 - loss: 0.8961 - val_accuracy: 0.8988 - val_loss: 0.4427
# Epoch 26/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8634 - loss: 0.8995 - val_accuracy: 0.8958 - val_loss: 0.4586
# Epoch 27/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8636 - loss: 0.9121 - val_accuracy: 0.8923 - val_loss: 0.4675
# Epoch 28/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8636 - loss: 0.9173 - val_accuracy: 0.9123 - val_loss: 0.4132
# Epoch 29/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8674 - loss: 0.8979 - val_accuracy: 0.9110 - val_loss: 0.4209
# Epoch 30/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8663 - loss: 0.8934 - val_accuracy: 0.9077 - val_loss: 0.4359
# Epoch 31/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8686 - loss: 0.8882 - val_accuracy: 0.9010 - val_loss: 0.4399
# Epoch 32/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8663 - loss: 0.8998 - val_accuracy: 0.9005 - val_loss: 0.4448
# Epoch 33/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8663 - loss: 0.8960 - val_accuracy: 0.9073 - val_loss: 0.4277
# Epoch 34/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8692 - loss: 0.8920 - val_accuracy: 0.9155 - val_loss: 0.4268
# Epoch 35/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8687 - loss: 0.8862 - val_accuracy: 0.9100 - val_loss: 0.4316
# Epoch 36/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8734 - loss: 0.8747 - val_accuracy: 0.8965 - val_loss: 0.4407
# Epoch 37/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8721 - loss: 0.8800 - val_accuracy: 0.9017 - val_loss: 0.4561
# Epoch 38/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8726 - loss: 0.8708 - val_accuracy: 0.8922 - val_loss: 0.4493
# Epoch 39/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8698 - loss: 0.8881 - val_accuracy: 0.9148 - val_loss: 0.4214
# Epoch 40/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8692 - loss: 0.8845 - val_accuracy: 0.9100 - val_loss: 0.4173
# Epoch 41/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8726 - loss: 0.8703 - val_accuracy: 0.9122 - val_loss: 0.3888
# Epoch 42/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8719 - loss: 0.8799 - val_accuracy: 0.9208 - val_loss: 0.3948
# Epoch 43/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8746 - loss: 0.8619 - val_accuracy: 0.8740 - val_loss: 0.4860
# Epoch 44/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8718 - loss: 0.8710 - val_accuracy: 0.9142 - val_loss: 0.4048
# Epoch 45/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8741 - loss: 0.8632 - val_accuracy: 0.8997 - val_loss: 0.4293
# Epoch 46/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8738 - loss: 0.8707 - val_accuracy: 0.9057 - val_loss: 0.4314
# Epoch 47/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8766 - loss: 0.8573 - val_accuracy: 0.9155 - val_loss: 0.3775
# Epoch 48/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8758 - loss: 0.8618 - val_accuracy: 0.9153 - val_loss: 0.3903
# Epoch 49/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8773 - loss: 0.8635 - val_accuracy: 0.9078 - val_loss: 0.4213
# Epoch 50/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8752 - loss: 0.8696 - val_accuracy: 0.9183 - val_loss: 0.3953
# Epoch 51/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8771 - loss: 0.8735 - val_accuracy: 0.9150 - val_loss: 0.4104
# Epoch 52/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8784 - loss: 0.8509 - val_accuracy: 0.9238 - val_loss: 0.3781
# Epoch 53/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8776 - loss: 0.8603 - val_accuracy: 0.9162 - val_loss: 0.3943
# Epoch 54/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8769 - loss: 0.8565 - val_accuracy: 0.9170 - val_loss: 0.3871
# Epoch 55/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8805 - loss: 0.8448 - val_accuracy: 0.9207 - val_loss: 0.3867
# Epoch 56/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8817 - loss: 0.8410 - val_accuracy: 0.9018 - val_loss: 0.4349
# Epoch 57/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8763 - loss: 0.8538 - val_accuracy: 0.9063 - val_loss: 0.4116
# Epoch 58/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8823 - loss: 0.8428 - val_accuracy: 0.9228 - val_loss: 0.3864
# Epoch 59/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8813 - loss: 0.8453 - val_accuracy: 0.9132 - val_loss: 0.4029
# Epoch 60/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8813 - loss: 0.8396 - val_accuracy: 0.9115 - val_loss: 0.4044
# Epoch 61/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8822 - loss: 0.8455 - val_accuracy: 0.9152 - val_loss: 0.3991
# Epoch 62/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8792 - loss: 0.8492 - val_accuracy: 0.9023 - val_loss: 0.4175
# Epoch 63/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8804 - loss: 0.8541 - val_accuracy: 0.9117 - val_loss: 0.3807
# Epoch 64/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8829 - loss: 0.8374 - val_accuracy: 0.8957 - val_loss: 0.4266
# Epoch 65/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8830 - loss: 0.8405 - val_accuracy: 0.9275 - val_loss: 0.3542
# Epoch 66/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8802 - loss: 0.8383 - val_accuracy: 0.9183 - val_loss: 0.3868
# Epoch 67/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8814 - loss: 0.8332 - val_accuracy: 0.9235 - val_loss: 0.3941
# Epoch 68/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8826 - loss: 0.8392 - val_accuracy: 0.9133 - val_loss: 0.3876
# Epoch 69/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8858 - loss: 0.8353 - val_accuracy: 0.9280 - val_loss: 0.3600
# Epoch 70/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8829 - loss: 0.8213 - val_accuracy: 0.9187 - val_loss: 0.3809
# Epoch 71/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8821 - loss: 0.8289 - val_accuracy: 0.9192 - val_loss: 0.3898
# Epoch 72/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8841 - loss: 0.8338 - val_accuracy: 0.9120 - val_loss: 0.3785
# Epoch 73/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8871 - loss: 0.8216 - val_accuracy: 0.9140 - val_loss: 0.3820
# Epoch 74/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8837 - loss: 0.8253 - val_accuracy: 0.9153 - val_loss: 0.3843
# Epoch 75/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8876 - loss: 0.8180 - val_accuracy: 0.9277 - val_loss: 0.3653
# Epoch 76/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8879 - loss: 0.8099 - val_accuracy: 0.9212 - val_loss: 0.3747
# Epoch 77/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8874 - loss: 0.8117 - val_accuracy: 0.9282 - val_loss: 0.3624
# Epoch 78/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8882 - loss: 0.8023 - val_accuracy: 0.9222 - val_loss: 0.3782
# Epoch 79/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8870 - loss: 0.8173 - val_accuracy: 0.9210 - val_loss: 0.3789
# Epoch 80/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8849 - loss: 0.8196 - val_accuracy: 0.9203 - val_loss: 0.3741
# Epoch 81/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8873 - loss: 0.8140 - val_accuracy: 0.9168 - val_loss: 0.3844
# Epoch 82/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8871 - loss: 0.8004 - val_accuracy: 0.9235 - val_loss: 0.3443
# Epoch 83/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8871 - loss: 0.8175 - val_accuracy: 0.9308 - val_loss: 0.3405
# Epoch 84/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8899 - loss: 0.8053 - val_accuracy: 0.9182 - val_loss: 0.3664
# Epoch 85/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8886 - loss: 0.8027 - val_accuracy: 0.9242 - val_loss: 0.3570
# Epoch 86/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8915 - loss: 0.7943 - val_accuracy: 0.9247 - val_loss: 0.3573
# Epoch 87/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8922 - loss: 0.7867 - val_accuracy: 0.9313 - val_loss: 0.3489
# Epoch 88/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8944 - loss: 0.7765 - val_accuracy: 0.9215 - val_loss: 0.3618
# Epoch 89/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8909 - loss: 0.7933 - val_accuracy: 0.9222 - val_loss: 0.3515
# Epoch 90/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8907 - loss: 0.7864 - val_accuracy: 0.9110 - val_loss: 0.3765
# Epoch 91/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8945 - loss: 0.7879 - val_accuracy: 0.9235 - val_loss: 0.3531
# Epoch 92/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8926 - loss: 0.7904 - val_accuracy: 0.9265 - val_loss: 0.3532
# Epoch 93/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8922 - loss: 0.8040 - val_accuracy: 0.9270 - val_loss: 0.3354
# Epoch 94/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8946 - loss: 0.7919 - val_accuracy: 0.9257 - val_loss: 0.3412
# Epoch 95/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8945 - loss: 0.7809 - val_accuracy: 0.9305 - val_loss: 0.3262
# Epoch 96/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8945 - loss: 0.7833 - val_accuracy: 0.9218 - val_loss: 0.3527
# Epoch 97/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8941 - loss: 0.7921 - val_accuracy: 0.9253 - val_loss: 0.3494
# Epoch 98/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8971 - loss: 0.7742 - val_accuracy: 0.9257 - val_loss: 0.3499
# Epoch 99/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8925 - loss: 0.7853 - val_accuracy: 0.9322 - val_loss: 0.3284
# Epoch 100/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8957 - loss: 0.7670 - val_accuracy: 0.9328 - val_loss: 0.3493
# Epoch 101/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8971 - loss: 0.7576 - val_accuracy: 0.9283 - val_loss: 0.3513
# Epoch 102/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8978 - loss: 0.7842 - val_accuracy: 0.9197 - val_loss: 0.3610
# Epoch 103/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8966 - loss: 0.7731 - val_accuracy: 0.9268 - val_loss: 0.3266
# Epoch 104/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8971 - loss: 0.7707 - val_accuracy: 0.9325 - val_loss: 0.3386
# Epoch 105/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8962 - loss: 0.7781 - val_accuracy: 0.9345 - val_loss: 0.3231
# Epoch 106/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8971 - loss: 0.7706 - val_accuracy: 0.9380 - val_loss: 0.3133
# Epoch 107/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8984 - loss: 0.7691 - val_accuracy: 0.9270 - val_loss: 0.3357
# Epoch 108/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8989 - loss: 0.7565 - val_accuracy: 0.9300 - val_loss: 0.3265
# Epoch 109/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8992 - loss: 0.7672 - val_accuracy: 0.9335 - val_loss: 0.3264
# Epoch 110/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.8976 - loss: 0.7648 - val_accuracy: 0.9283 - val_loss: 0.3142
# Epoch 111/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9009 - loss: 0.7542 - val_accuracy: 0.9368 - val_loss: 0.3048
# Epoch 112/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9016 - loss: 0.7518 - val_accuracy: 0.9305 - val_loss: 0.3182
# Epoch 113/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9009 - loss: 0.7693 - val_accuracy: 0.9263 - val_loss: 0.3396
# Epoch 114/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9017 - loss: 0.7510 - val_accuracy: 0.9257 - val_loss: 0.3198
# Epoch 115/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9047 - loss: 0.7269 - val_accuracy: 0.9257 - val_loss: 0.3160
# Epoch 116/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9022 - loss: 0.7503 - val_accuracy: 0.9317 - val_loss: 0.3141
# Epoch 117/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9036 - loss: 0.7392 - val_accuracy: 0.9358 - val_loss: 0.3034
# Epoch 118/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9031 - loss: 0.7508 - val_accuracy: 0.9222 - val_loss: 0.3354
# Epoch 119/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9030 - loss: 0.7499 - val_accuracy: 0.9330 - val_loss: 0.3071
# Epoch 120/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9032 - loss: 0.7490 - val_accuracy: 0.9392 - val_loss: 0.3074
# Epoch 121/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9040 - loss: 0.7438 - val_accuracy: 0.9305 - val_loss: 0.3133
# Epoch 122/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9025 - loss: 0.7426 - val_accuracy: 0.9313 - val_loss: 0.3071
# Epoch 123/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9047 - loss: 0.7384 - val_accuracy: 0.9352 - val_loss: 0.2978
# Epoch 124/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9036 - loss: 0.7392 - val_accuracy: 0.9358 - val_loss: 0.3172
# Epoch 125/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9062 - loss: 0.7418 - val_accuracy: 0.9300 - val_loss: 0.3104
# Epoch 126/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9057 - loss: 0.7327 - val_accuracy: 0.9197 - val_loss: 0.3215
# Epoch 127/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9083 - loss: 0.7264 - val_accuracy: 0.9333 - val_loss: 0.3016
# Epoch 128/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9061 - loss: 0.7334 - val_accuracy: 0.9350 - val_loss: 0.2927
# Epoch 129/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9099 - loss: 0.7101 - val_accuracy: 0.9358 - val_loss: 0.2937
# Epoch 130/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9091 - loss: 0.7038 - val_accuracy: 0.9327 - val_loss: 0.2984
# Epoch 131/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9092 - loss: 0.7162 - val_accuracy: 0.9368 - val_loss: 0.2984
# Epoch 132/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9086 - loss: 0.7143 - val_accuracy: 0.9390 - val_loss: 0.2885
# Epoch 133/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9127 - loss: 0.7113 - val_accuracy: 0.9347 - val_loss: 0.2927
# Epoch 134/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9086 - loss: 0.7151 - val_accuracy: 0.9375 - val_loss: 0.2922
# Epoch 135/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9125 - loss: 0.7099 - val_accuracy: 0.9353 - val_loss: 0.3000
# Epoch 136/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9102 - loss: 0.7158 - val_accuracy: 0.9368 - val_loss: 0.2854
# Epoch 137/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9099 - loss: 0.7183 - val_accuracy: 0.9385 - val_loss: 0.2800
# Epoch 138/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9122 - loss: 0.7092 - val_accuracy: 0.9377 - val_loss: 0.2842
# Epoch 139/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9130 - loss: 0.6851 - val_accuracy: 0.9382 - val_loss: 0.2827
# Epoch 140/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9126 - loss: 0.7120 - val_accuracy: 0.9377 - val_loss: 0.2771
# Epoch 141/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9145 - loss: 0.6854 - val_accuracy: 0.9373 - val_loss: 0.2790
# Epoch 142/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9147 - loss: 0.6906 - val_accuracy: 0.9398 - val_loss: 0.2804
# Epoch 143/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9128 - loss: 0.7061 - val_accuracy: 0.9397 - val_loss: 0.2716
# Epoch 144/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9153 - loss: 0.6820 - val_accuracy: 0.9375 - val_loss: 0.2764
# Epoch 145/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9168 - loss: 0.6828 - val_accuracy: 0.9302 - val_loss: 0.2862
# Epoch 146/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9174 - loss: 0.6941 - val_accuracy: 0.9398 - val_loss: 0.2704
# Epoch 147/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9148 - loss: 0.6854 - val_accuracy: 0.9420 - val_loss: 0.2701
# Epoch 148/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9167 - loss: 0.6785 - val_accuracy: 0.9402 - val_loss: 0.2603
# Epoch 149/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9170 - loss: 0.6732 - val_accuracy: 0.9413 - val_loss: 0.2603
# Epoch 150/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9178 - loss: 0.6810 - val_accuracy: 0.9337 - val_loss: 0.2816
# Epoch 151/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9163 - loss: 0.6866 - val_accuracy: 0.9442 - val_loss: 0.2697
# Epoch 152/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9182 - loss: 0.6942 - val_accuracy: 0.9425 - val_loss: 0.2601
# Epoch 153/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9182 - loss: 0.6863 - val_accuracy: 0.9388 - val_loss: 0.2594
# Epoch 154/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9203 - loss: 0.6667 - val_accuracy: 0.9427 - val_loss: 0.2523
# Epoch 155/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9200 - loss: 0.6794 - val_accuracy: 0.9433 - val_loss: 0.2665
# Epoch 156/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9216 - loss: 0.6645 - val_accuracy: 0.9438 - val_loss: 0.2598
# Epoch 157/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9198 - loss: 0.6652 - val_accuracy: 0.9438 - val_loss: 0.2604
# Epoch 158/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9220 - loss: 0.6647 - val_accuracy: 0.9412 - val_loss: 0.2588
# Epoch 159/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9243 - loss: 0.6519 - val_accuracy: 0.9445 - val_loss: 0.2547
# Epoch 160/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9219 - loss: 0.6615 - val_accuracy: 0.9423 - val_loss: 0.2520
# Epoch 161/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9213 - loss: 0.6660 - val_accuracy: 0.9445 - val_loss: 0.2509
# Epoch 162/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9216 - loss: 0.6687 - val_accuracy: 0.9457 - val_loss: 0.2451
# Epoch 163/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9235 - loss: 0.6532 - val_accuracy: 0.9438 - val_loss: 0.2459
# Epoch 164/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9221 - loss: 0.6558 - val_accuracy: 0.9452 - val_loss: 0.2483
# Epoch 165/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9261 - loss: 0.6450 - val_accuracy: 0.9447 - val_loss: 0.2391
# Epoch 166/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9226 - loss: 0.6669 - val_accuracy: 0.9438 - val_loss: 0.2551
# Epoch 167/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9252 - loss: 0.6450 - val_accuracy: 0.9428 - val_loss: 0.2412
# Epoch 168/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9257 - loss: 0.6551 - val_accuracy: 0.9450 - val_loss: 0.2325
# Epoch 169/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9242 - loss: 0.6500 - val_accuracy: 0.9437 - val_loss: 0.2418
# Epoch 170/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9256 - loss: 0.6529 - val_accuracy: 0.9430 - val_loss: 0.2403
# Epoch 171/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9267 - loss: 0.6657 - val_accuracy: 0.9445 - val_loss: 0.2422
# Epoch 172/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9259 - loss: 0.6490 - val_accuracy: 0.9457 - val_loss: 0.2447
# Epoch 173/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9270 - loss: 0.6543 - val_accuracy: 0.9472 - val_loss: 0.2433
# Epoch 174/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9266 - loss: 0.6491 - val_accuracy: 0.9443 - val_loss: 0.2442
# Epoch 175/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9256 - loss: 0.6651 - val_accuracy: 0.9458 - val_loss: 0.2427
# Epoch 176/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9290 - loss: 0.6321 - val_accuracy: 0.9443 - val_loss: 0.2397
# Epoch 177/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.9291 - loss: 0.6299 - val_accuracy: 0.9445 - val_loss: 0.2371
# Epoch 178/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9273 - loss: 0.6443 - val_accuracy: 0.9447 - val_loss: 0.2391
# Epoch 179/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9271 - loss: 0.6560 - val_accuracy: 0.9443 - val_loss: 0.2396
# Epoch 180/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9280 - loss: 0.6467 - val_accuracy: 0.9445 - val_loss: 0.2412
# Epoch 181/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9282 - loss: 0.6431 - val_accuracy: 0.9448 - val_loss: 0.2403
# Epoch 182/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9282 - loss: 0.6366 - val_accuracy: 0.9442 - val_loss: 0.2410
# Epoch 183/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9296 - loss: 0.6382 - val_accuracy: 0.9448 - val_loss: 0.2382
# Epoch 184/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9300 - loss: 0.6375 - val_accuracy: 0.9445 - val_loss: 0.2351
# Epoch 185/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9303 - loss: 0.6264 - val_accuracy: 0.9460 - val_loss: 0.2319
# Epoch 186/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9315 - loss: 0.6180 - val_accuracy: 0.9462 - val_loss: 0.2349
# Epoch 187/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9311 - loss: 0.6163 - val_accuracy: 0.9468 - val_loss: 0.2314
# Epoch 188/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9295 - loss: 0.6402 - val_accuracy: 0.9455 - val_loss: 0.2336
# Epoch 189/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9284 - loss: 0.6470 - val_accuracy: 0.9457 - val_loss: 0.2376
# Epoch 190/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9280 - loss: 0.6475 - val_accuracy: 0.9463 - val_loss: 0.2348
# Epoch 191/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9304 - loss: 0.6363 - val_accuracy: 0.9453 - val_loss: 0.2363
# Epoch 192/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9305 - loss: 0.6323 - val_accuracy: 0.9460 - val_loss: 0.2361
# Epoch 193/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9330 - loss: 0.6155 - val_accuracy: 0.9467 - val_loss: 0.2324
# Epoch 194/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.9326 - loss: 0.6162 - val_accuracy: 0.9470 - val_loss: 0.2304
# Epoch 195/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9325 - loss: 0.6230 - val_accuracy: 0.9473 - val_loss: 0.2323
# Epoch 196/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9306 - loss: 0.6381 - val_accuracy: 0.9468 - val_loss: 0.2378
# Epoch 197/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9322 - loss: 0.6234 - val_accuracy: 0.9462 - val_loss: 0.2352
# Epoch 198/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.9310 - loss: 0.6265 - val_accuracy: 0.9468 - val_loss: 0.2302
# Epoch 199/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9327 - loss: 0.6157 - val_accuracy: 0.9467 - val_loss: 0.2344
# Epoch 200/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.9302 - loss: 0.6297 - val_accuracy: 0.9467 - val_loss: 0.2327
# Restoring model weights from the end of the best epoch: 195.
# [✓] Model saved: /kaggle/working/best_fashion_model.keras
#
# ============================================================
# TEST SET METRICS
# ============================================================
#
#   Accuracy           : 0.9436 (94.36%)
#   Precision (macro)  : 0.9437
#   Recall (macro)     : 0.9436
#   F1-score (macro)   : 0.9436
#   Precision (weighted): 0.9437
#   Recall (weighted)  : 0.9436
#   F1 (weighted)      : 0.9436
#
#   --- Per-class metrics ---
#   Kelas             Precision   Recall       F1
#   -------------------------------------
#   0 T-shirt/top     0.8999   0.9080   0.9039
#   1 Trouser         0.9940   0.9920   0.9930
#   2 Pullover        0.9166   0.9120   0.9143
#   3 Dress           0.9391   0.9400   0.9395
#   4 Coat            0.9210   0.9210   0.9210
#   5 Sandal          0.9909   0.9820   0.9864
#   6 Shirt           0.8377   0.8360   0.8368
#   7 Sneaker         0.9638   0.9840   0.9738
#   8 Bag             0.9940   0.9920   0.9930
#   9 Ankle boot      0.9798   0.9690   0.9744
#
#   Inference time : 5.392 ms/gambar
#   Model size     : 7.59 MB
#   Total params   : 1,989,579
# [✓] Confusion matrix saved
# [✓] Training history saved
# [✓] Pareto front saved
# [✓] All results saved: /kaggle/working/fashion_nslso_results.json
#
# ============================================================
# NS-LSO FASHION-MNIST COMPLETED
# ============================================================
